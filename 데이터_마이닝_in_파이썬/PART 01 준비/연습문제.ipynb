# %% [markdown]
# ## 연습문제

# %% [markdown]
# ### 2.1

# %% [markdown]
# #### 다음 문제를 데이터 마이닝 기법을 이용해 해결하려고 한다. 지도 학습과 비지도 학습 중 어느 기법을 사용하는 것이 적절한지 구분하시오.

# %% [markdown]
# ##### a. 과거 고객들의 인구통계학적 데이터와 금융 데이터를 바탕으로 새로운 고객들의 대출 여부 결정

# %% [markdown]
# - 지도 학습, 과거 고객들의 데이터를 바탕으로 미래 고객 고객의 대출 여부 **예측**을 수행하는 것이기 때문

# %% [markdown]
# ##### b. 온라인 서점에서 기존 구매 고객들의 구매 패턴을 파악해 책 추천

# %% [markdown]
# - 비지도 학습, 추천 시스템을 구축할 때는 주로 비지도 학습 기법으로 기존 고객들의 구매 패턴을 분석하여 유사한 사용자나 아이템을 기반으로 추천을 수행합니다.

# %% [markdown]
# ##### c. 기존에 알고 있는 네트워크 데이터 패킷 상태 정보를 이용해 새로운 네트워크 데이터 패킷의 상태 분류(예. 바이러스, 해커 공격)

# %% [markdown]
# - 지도 학습, 기존 데이터를 활용해서 새로운 데이터의 상태를 **분류**를 수행하는 것이기 때문

# %% [markdown]
# ##### d. 비슷한 성향인 고객군 파악

# %% [markdown]
# - 비지도 학습, 주어진 레이블이 없는 고객 데이터를 사용해 유사한 성향을 그룹화하는 분류 문제이기 때문

# %% [markdown]
# ##### e. 파산한 회사와 그렇지 않은 회사들의 재정 상태 데이터를 기반으로 특정 회사의 파산 여부 예측

# %% [markdown]
# - 지도 학습, 과거 데이터를 활용해 미래 데이터를 예측하는 것이기 때문

# %% [markdown]
# ##### f. 수리 이력 정보를 바탕으로 항공기 수리 시간 추정

# %% [markdown]
# - 지도 학습, 과거 데이터를 활용해 얻고자 하는 모델을 예측하는 것이기 때문

# %% [markdown]
# ##### g. 우편번호 스캔 결과 정보를 바탕으로 우편물 자동 분류

# %% [markdown]
# 지도 학습, 이미 존재하는 데이터를 기반으로 자동으로 분류하는 모델을 예측하는 것이기 때문

# %% [markdown]
# ##### h. 본인의 구매 물품과 다른 고객들의 과거 구매 이력 정보를 바탕으로 할인 쿠폰의 발행 여부 판단

# %% [markdown]
# - 지도 학습, 과거 데이터를 활용해 미래 데이터의 구조를 예측하는 문제이기 때문

# %% [markdown]
# ### 2.2

# %% [markdown]
# #### 검증 데이터와 테스트 데이터의 차이를 설명하시오.

# %% [markdown]
# - 검증 데이터 : Validation data로, 모델이 얼마나 적합한지 테스트 후 모델을 조정해 보면서 최적 모델을 결정하는 데 사용한 일부 데이터 (학습 데이터로부터 구축된 여러 모델의 성능 비교 시 사용)
# - 테스트 데이터 : Testing data로, 구축 모델이 향후 데이터에 얼마만큼 예측/분류 성능을 보일지 평가 (미래값의 정확한 예측이 불필요하다면 미사용)

# %% [markdown]
# ### 2.3

# %% [markdown]
# #### [표 2-16]은 신용카드 신청자 데이터의 일부다. 이 데이터가 랜덤하게 샘플링된 것인지, 분석에 적절하게 사용될 수 있을지에 대해 논해 보시오.
#
# ![03.png](attachment:03.png)

# %% [markdown]
# - 샘플링된 데이터는 가구, 라디오 티브이 등을 볼때 불필요한 요소라고 생각이 들고, 자금의 변동성에 큰 영향을 주는 NEW CAR나 USED CAR 값의 편차가 크지 않은 것을 통해 모집단에 대한 대표를 할 수 있는지 의심이 가기 때문에 무작위로 랜덤하게 데이터가 샘플링된 것으로 간주되며 분석에 적절하게 사용될 수 없다고 판단된다.

# %% [markdown]
# ### 2.4

# %% [markdown]
# #### [표 2-17]은 은행 데이터베이스에서 학습 데이터를 구성하기 위해 랜덤하게 추출한 데이터다. Personal loan(개인대출) 변수는 은행이 실시한 융자 권유에 대해 고객의 수락 여부를 보여주는 변수다(1: 수락). 은행은 이 데이터를 바탕으로 예측 모델을 구축해 미래의 융자 수락 고객들을 예측해 보고자 한다. 이를 위해 어떤 분석을 해야 하는지 서술하시오.
#
# ![04.png](attachment:04.png)

# %% [markdown]
# - 우선, 불필요한 요소인 우편번호를 제거하고, 은행의 융자 권유에 수락한 고객의 나이, 수입, 부양 가족 수, 교육 수준, 빚 등을 실질적인 학습 데이터로 모델 구축을 시작한다.
# -

# %% [markdown]
# ### 2.5

# %% [markdown]
# #### 구축된 모델을 학습 데이터에 적용할 경우 오차가 0이 나올 수 있다. 과적합의 개념을 이용해 이 경우가 좋지 않을 수도 있음을 설명하시오.

# %% [markdown]
# ### 2.6

# %% [markdown]
# #### 고객을 구매자와 비구매자로 분류하기 위해 고객 신상 정보와 구매 정보를 이용해 분류 모델을 구축하였다. 여기서 refund issued(환불 여부)가 분류에 중요한 역할을 하는 변수임을 알았다. 앞으로 분류하려고 하는 데이터에 고객 신상 정보는 있지만 구매 정보는 없다고 가정하면 refund issued 변수를 모델 구축 시 포함시켜서는 안 되는 이유를 설명하시오.

# %% [markdown]
# ### 2.7

# %% [markdown]
# #### 1,000개의 관측치와 50개의 변수, 5%의 결측치가 랜덤하게 존재하는 데이터가 있다고 가정하자. 결측치를 모두 삭제한다면 총 몇 개의 관측치가 삭제되는지 계산해 보시오.

# %% [markdown]
# ### 2.8

# %% [markdown]
# #### [표 2-18]의 데이터를 정규화하시오(계산 과정을 명시하시오).
#
# ![05.png](attachment:05.png)

# %% [markdown]
# ### 2.9

# %% [markdown]
# #### 관측치들의 거리를 계산하는 다양한 방법 중 유클리드 거리를 이용해 [표 2-18]의 첫 번째와 두 번째 관측치 사이의 거리를 다음 식으로 구할 수 있다. 데이터를 정규화함으로써 두 관측치 사이의 유클리드 거리가 더 멀어질 수 있을지에 관해 설명해 보시오.
#
# ![06.png](attachment:06.png)
#
# &radic;{(25-56)^2+(49,000-156,000)^2}

# %% [markdown]
# ### 2.10

# %% [markdown]
# #### 분할된 데이터에 2개의 모델을 적용햇다. 모델 A는 모델 B보다 학습 데이터에서 더 좋은 성능을 보였다. 그러나 검증 데이터에서는 모델 B가 근소한 차이로 좋은 성능을 보였다. 어느 모델을 선택할지 명시하고 그 이유를 쓰시오.

# %% [markdown]
# ### 2.11

# %% [markdown]
# #### ToyotaCorolla.csv 데이터는 2004년 늦여름 네덜란드에서 판매한 중고 자동차 판매 정보다. 1,436개의 관측치와 자동차 가격, 연식, 마력 등 38개의 변수를 포함하고 있다. 이 데이터를 다양한 데이터 마이닝 기법에 적용하기 전에 다음 작업을 수행하시오.

# %% [markdown]
# ##### a.

# %% [markdown]
# ###### Fuel Type 변수와 Metallic 변수는 범주형이다. 어떤 방식으로 이 변수들을 가변수로 변환할지 설명하시오. 파이썬 pandas를 이용해 범주형 변수를 가변수로 변환하시오.

# %% [markdown]
# ##### b.

# %% [markdown]
# ###### 파이썬을 이용해 이 데이터를 학습 데이터(50%), 검증 데이터(30%), 테스트 데이터(20%)로 분할하고 각각의 역할을 설명하시오(분할 시 모든 변수를 사용하고 초깃값은 기본값을 사용하시오).
